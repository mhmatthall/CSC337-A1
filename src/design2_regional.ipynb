# %% [markdown]
# # CSC337: Coursework 1
#
# ## Task 1: Design 2
# ### Box plots to show the age of global power plants by primary fuel type
# <b>Visual Design Type:</b> Box plot
#
# <b>Name of Tool:</b> Altair
#
# <b>Country:</b> Global aggregate
#
# <b>Year:</b> N/A
#
# <b>Visual Mappings:</b>
# + Box plots show the distribution of power plant age for each fuel type;
#     + the whiskers show <i>relative</i> minimum/maximum ages of the plants
#
#     + the filled box illustrates the IQR of the age
#
#     + the black line in the box indicates the median age
#
# + Colour is used to discern renewable from non-renewable energy sources
#
# Additionally, the following points were deliberated:
# + Whiskers do not show true min/max values for the plants, as extremely old plants were skewing the distributions. Instead, the whiskers show plants within an age of 0.5x the IQR for the fuel type

# %%
import pandas as pd
import geopandas as gpd
import altair as alt
import datetime as dt
import json

# %% [markdown]
# Debug options

# %%
# font to use for chart labels
__CHART_FONT__ = 'Circular'

# DEBUG: disable maximum row prevention (cripples chart performance)
alt.data_transformers.disable_max_rows()

# DEBUG: set max rows/columns in pandas table previewer
# pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# Load the GPPD data set and sequentially derive the required information

# %%
# load GPPD data set into pandas array
d_plants = pd.read_csv('../data/global_power_plant_database.csv')

# keep only necessary columns
d_boxplot = d_plants[['commissioning_year', 'primary_fuel']]

# retrieve GeoJSON data
with open('world.json') as world:
    world_map_data = json.load(world)

# keep only region data
d_regions = gpd.GeoDataFrame.from_features(
    world_map_data
)#[['iso_a3', 'subregion']]

d_boxplot['region'] = d_plants.merge(
    d_regions,
    how='left',
    left_on='country',
    right_on='iso_a3'
)[['region_wb']]


# remove null data from combined column
d_boxplot.dropna(
    subset=['commissioning_year', 'region'],
    inplace=True
)

# remove plants of type storage because they don't generate power
d_boxplot = d_boxplot[d_boxplot['primary_fuel'] != 'Storage']

# calculate age of plants
d_boxplot['age'] = dt.datetime.now().year - d_boxplot['commissioning_year']

d_regions

# # colour the box plots based on whether fuel type is renewable
# d_boxplot['Renewable'] = d_boxplot['primary_fuel'].isin(['Biomass', 'Geothermal', 'Hydro', 'Solar', 'Wind'])

# # replace renewability True/False with Yes/No for better presentation
# d_boxplot.replace(
#     {True: 'Yes', False: 'No'},
#     inplace=True
# )
# Out:
# aran Africa         4        4          4   -99        1
# 85   Middle East & North Africa         7        7          4   -99        1
# 86           Sub-Saharan Africa         4        4          4   -99        1
# 87           Sub-Saharan Africa         8        8          5   -99        1
# 88           Sub-Saharan Africa         6        6          4   -99        1
# 89           Sub-Saharan Africa        12       12          5   -99        1
# 90           Sub-Saharan Africa         6        6          6   -99        1
# 91           Sub-Saharan Africa         8        8          5   -99        1
# 92          East Asia & Pacific        14       14          9     3      -99
# 93          East Asia & Pacific        23       27          7   -99      -99
# 94          East Asia & Pacific         9        9          4   -99        1
# 95          East Asia & Pacific         8       12          8     3      -99
# 96          East Asia & Pacific         4        4          4   -99        1
# 97          East Asia & Pacific        10       30          6   -99        1
# 98          East Asia & Pacific         4        4          4     2      -99
# 99          East Asia & Pacific         8        8          4     2        1
# 100         East Asia & Pacific        12       16          6     2        1
# 101         East Asia & Pacific        14       24          6     3      -99
# 102         East Asia & Pacific        13       13          6   -99      -99
# 103         East Asia & Pacific         5        5          5     3        1
# 104         East Asia & Pacific        14       14          7   -99      -99
# 105         East Asia & Pacific         4        4          4     3      -99
# 106         East Asia & Pacific        11       11          4   -99        1
# 21                   KNA.geojson
# 22                   LCA.geojson
# 23                   MAF.geojson
# 24                   MSR.geojson
# 25                   MEX.geojson
# 26                   NIC.geojson
# 27                   PAN.geojson
# 28                   PRI.geojson
# 29                   SLV.geojson
# 30                   SPM.geojson
# 31                   SXM.geojson
# 32                   TCA.geojson
# 33                   TTO.geojson
# 34                   USA.geojson
# 35                   VCT.geojson
# 36                   VGB.geojson
# 37                   AGO.geojson
# 38                   BDI.geojson
# 39                   BEN.geojson
# 40                   VIR.geojson
# 41                   BFA.geojson
# 42                   BWA.geojson
# 43                   CAF.geojson
# 44                   COG.geojson
# 45                   CIV.geojson
# 46                   CMR.geojson
# 47                   COD.geojson
# 48                   COM.geojson
# 49                   CPV.geojson
# 50                   DJI.geojson
# 51                   DZA.geojson
# 52                   EGY.geojson
# 53                   ERI.geojson
# 54                   ETH.geojson
# 55                   GAB.geojson
# 56                   GHA.geojson
# 57                   GIN.geojson
# 58                   GMB.geojson
# 59                   GNB.geojson
# 60                   GNQ.geojson
# 61                   KEN.geojson
# 62                   LBR.geojson
# 63                   MAR.geojson
# 64                   MDG.geojson
# 65                   LBY.geojson
# 66                   MLI.geojson
# 67                   LSO.geojson
# 68                   MOZ.geojson
# 69                   MWI.geojson
# 70                   NER.geojson
# 71                   NGA.geojson
# 72                   MRT.geojson
# 73                   NAM.geojson
# 74                   RWA.geojson
# 75                   ESH.geojson
# 76                   SDN.geojson
# 77                   SSD.geojson
# 78                   SEN.geojson
# 79                   SLE.geojson
# 80            somaliland.geojson
# 81                   SOM.geojson
# 82                   STP.geojson
# 83                   SWZ.geojson
# 84                   TCD.geojson
# 85                   TUN.geojson
# 86                   TGO.geojson
# 87                   TZA.geojson
# 88                   UGA.geojson
# 89                   ZAF.geojson
# 90                   ZMB.geojson
# 91                   ZWE.geojson
# 92                   ASM.geojson
# 93   ashmoreandcartieris.geojson
# 94                   AUS.geojson
# 95                   COK.geojson
# 96                   FJI.geojson
# 97                   FSM.geojson
# 98                   GUM.geojson
# 99                   KIR.geojson
# 100                  MHL.geojson
# 101                  MNP.geojson
# 102                  NCL.geojson
# 103                  NRU.geojson
# 104                  NFK.geojson
# 105                  NIU.geojson
# 106                  NZL.geojson
# 107                  PCN.geojson
# 108                  PLW.geojson
# 109                  SLB.geojson
# 110                  PNG.geojson
# 111                  PYF.geojson
# 112                  TON.geojson
# 113                  VUT.geojson
# 114                  WLF.geojson
# 115                  WSM.geojson
# 116                  ARG.geojson
# 117                  BOL.geojson
# 118                  BRA.geojson
# 119                  CHL.geojson
# 120                  ECU.geojson
# 121                  FLK.geojson
# 122                  GUY.geojson
# 123                  COL.geojson
# 124                  PER.geojson
# 125                  PRY.geojson
# 126                  SUR.geojson
# 127                  URY.geojson
# 128                  VEN.geojson
# 129                  AFG.geojson
# 130                  ARE.geojson
# 131                  ARM.geojson
# 132                  AZE.geojson
# 133                  BHR.geojson
# 134                  BRN.geojson
# 135                  BGD.geojson
# 136                  BTN.geojson
# 137                  CYN.geojson
# 138                  CHN.geojson
# 139                  CYP.geojson
# 140                  GEO.geojson
# 141                  HKG.geojson
# 142                  IDN.geojson
# 143                  IND.geojson
# 144       indianoceanter.geojson
# 145                  IRQ.geojson
# 146                  IRN.geojson
# 147                  ISR.geojson
# 148                  JOR.geojson
# 149                  JPN.geojson
# 150       siachenglacier.geojson
# 151                  KAZ.geojson
# 152                  KGZ.geojson
# 153                  KHM.geojson
# 154                  KOR.geojson
# 155                  KWT.geojson
# 156                  LAO.geojson
# 157                  LBN.geojson
# 158                  LKA.geojson
# 159                  MAC.geojson
# 160                  MMR.geojson
# 161                  MNG.geojson
# 162                  MYS.geojson
# 163                  NPL.geojson
# 164                  OMN.geojson
# 165                  PAK.geojson
# 166                  PHL.geojson
# 167                  PRK.geojson
# 168                  PSE.geojson
# 169                  QAT.geojson
# 170                  SAU.geojson
# 171                  SGP.geojson
# 172                  SYR.geojson
# 173                  THA.geojson
# 174                  TJK.geojson
# 175                  TKM.geojson
# 176                  TLS.geojson
# 177                  TUR.geojson
# 178                  TWN.geojson
# 179                  UZB.geojson
# 180                  VNM.geojson
# 181                  YEM.geojson
# 182                  ALB.geojson
# 183                  ALA.geojson
# 184                  AND.geojson
# 185                  AUT.geojson
# 186                  BEL.geojson
# 187                  BGR.geojson
# 188                  BIH.geojson
# 189                  BLR.geojson
# 190                  CHE.geojson
# 191                  CZE.geojson
# 192                  DEU.geojson
# 193                  DNK.geojson
# 194                  ESP.geojson
# 195                  EST.geojson
# 196                  FIN.geojson
# 197                  FRA.geojson
# 198                  FRO.geojson
# 199                  GBR.geojson
# 200                  GGY.geojson
# 201                  HRV.geojson
# 202                  GRC.geojson
# 203                  HUN.geojson
# 204                  IMN.geojson
# 205                  IRL.geojson
# 206                  ISL.geojson
# 207                  KOS.geojson
# 208                  ITA.geojson
# 209                  JEY.geojson
# 210                  LIE.geojson
# 211                  LTU.geojson
# 212                  LUX.geojson
# 213                  LVA.geojson
# 214                  MCO.geojson
# 215                  MDA.geojson
# 216                  MKD.geojson
# 217                  MLT.geojson
# 218                  MNE.geojson
# 219                  NLD.geojson
# 220                  NOR.geojson
# 221                  POL.geojson
# 222                  PRT.geojson
# 223                  ROU.geojson
# 224                  SMR.geojson
# 225                  RUS.geojson
# 226                  SRB.geojson
# 227                  SVK.geojson
# 228                  SVN.geojson
# 229                  SWE.geojson
# 230                  UKR.geojson
# 231                  VAT.geojson
#
# [232 rows x 65 columns]

# %% [markdown]
# Draw the visualisation

# %%
alt.Chart(
    data=d_boxplot,
    height=750,
    width=1000,
    padding=20,
    title=alt.TitleParams(
        text='Age of Power Plants by Region',
        fontSize=22,
        font=__CHART_FONT__
    )
).mark_boxplot(
    size=50,
    extent=0.5,
    outliers=False,
    median=alt.MarkConfig(
        stroke='black'
    )
).encode(
    x=alt.X(
        'region:N',
        axis=alt.Axis(
            title="Region",
            titleFontSize=18,
            titleFont=__CHART_FONT__,
            labelFontSize=14,
            labelFont=__CHART_FONT__,
            labelAngle=45
        ),
        # # this sort stopped working for some reason smh my head
        # sort=alt.SortField(
        #     field='Renewable'
        # )
    ),
    y=alt.Y(
        'age:Q',
        axis=alt.Axis(
            title='Age (years)',
            titleFontSize=18,
            titleFont=__CHART_FONT__,
            labelFontSize=14,
            labelFont=__CHART_FONT__,
            tickCount=20
        )
    ),
    color=alt.Color(
        # colour boxes red/blue based on renewability
        'region:N',
        # scale=alt.Scale(
        #     range=['#FF5722', '#00BCD4']
        # ),
        legend=alt.Legend(
            titleFontSize=18,
            titleFont=__CHART_FONT__,
            labelFontSize=16,
            labelFont=__CHART_FONT__
        )
    )
)
# Out:
# alt.Chart(...)
